# %%
# %matplotlib notebook
import skbio as skbio
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
PlankC=pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Micrograms_of_C_P.Plankton.csv')
RhizC=pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Micrograms_of_C_Rhizaria.csv')

dfCarbon_md= pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/4CSV_Biovolume_Carbon_4EXPORTS_.csv')
dfFluxes_md=pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Biovolume_&_Cell_to_Carbon_Conversions/cellfluxes4carbonvalues.csv')

unc_combined_df= pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/EXPORTS_Gel_115x_25x_7x_Uncertainties.csv')
combined_df= pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/EXPORTS_Gel_115x_25x_7x.csv')
dfA= pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/EXPORTS_gel_cell_cnt_grids_Jan_10.csv')
#
u_fluxes4carbon=pd.read_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Biovolume_&_Cell_to_Carbon_Conversions/unc_cellfluxes4carbonvalues.csv')
u_PlankC=pd.read_csv('/Users/alb/PROJECTS/copy_unc_Plank_C.csv')
u_RhizC=pd.read_csv('/Users/alb/PROJECTS/unc_Rhiz_C_copy.csv')

# %%
u_RhizC
# Out:
#                             iv          RR1        RR4          RR5  \
# iv
# Aulocanthidae    Aulocanthidae     0.000000  31.325867     0.000000
# Aulosphaeridae  Aulosphaeridae     0.000000  41.440227    54.257994
# Castanellidae    Castanellidae    15.662934  64.579930    71.776579
# Challengeridae  Challengeridae     0.000000   0.000000     0.000000
# Coelodendridae  Coelodendridae     0.000000   0.000000    35.023384
# Phaeoconchidae  Phaeoconchidae    15.662934  44.301466    15.662934
# Acanth_B              Acanth_B     0.000000   0.000000     0.000000
# Foram                    Foram   613.115330   0.000000     0.000000
# Cladococcus        Cladococcus    41.440227  27.128997     0.000000
# Litharachnium    Litharachnium     0.000000  31.325867    15.662934
# Nass_A_B-C-D-E  Nass_A_B-C-D-E  1459.506420   0.000000  1118.120450
# Nass_F                  Nass_F     0.000000   0.000000     0.000000
# Spum C                  Spum C     0.000000  15.662934    22.150733
# ...

# %%
RhizC.index=RhizC['iv']
RhizCx=RhizC.drop(['iv'],axis=1)

# %%
#Uncertainty of my summed fluxes: square unc-flux numbers. sum all. take square root unc_squared=unc_combined_df**2
#A_flux_sum=combined_df.sum(axis=0)
#unc_combined_df=dfB.drop([dfB.loc[dfB.Category=='Foraminifera'].index[0]])
#To get rid of all string headings!!! select_dtypes
#unc_combined_df_numbers=unc_combined_df.select_dtypes(include='float64')
#
#unc2=unc_combined_df_numbers**2
#unc3=unc2.sum(axis=0)
#unc_A_flux_sum=np.sqrt(unc3)

# %%
unc_combined_df.index=combined_df['Category']#making one row of taxonomy the index names
combined_df.index=combined_df['Category']#making one row of taxonomy the index names
combined_df_ready=combined_df.drop(['Unnamed: 0','Unnamed: 0.1','Subphylum'],axis=1)
unc_combined_df_ready=unc_combined_df.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1)
#unc_combined_df_ready.to_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Biovolume_&_Cell_to_Carbon_Conversions/unc_combined_df_ready.csv')
#combined_df_ready.to_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Biovolume_&_Cell_to_Carbon_Conversions/combined_df_ready.csv')
unc_combined_df_ready
# Out:
#                                 RR1          RR4          RR5          RR6  \
# Category
# Tintinnid_A              500.606571   526.954285   476.768163     0.000000
# Tintinnid_Dictyocysta      0.000000     0.000000     0.000000     0.000000
# Emiliania_(A)              0.000000     0.000000  1507.673310  4882.038777
# Helicosphaera_(B)          0.000000     0.000000     0.000000   699.818508
# Rhabdosphaera           1119.390322     0.000000     0.000000     0.000000
# Chaetocerous               0.000000     0.000000   891.951559     0.000000
# Corethron                  0.000000     0.000000     0.000000     0.000000
# Coscinodiscus            613.115330     0.000000   476.768163   903.461809
# Eucampia                   0.000000     0.000000     0.000000     0.000000
# Fragilariopsis             0.000000     0.000000  3071.364038  2020.202020
# Pennate_A                867.076015   372.612948     0.000000  1456.788394
# ...

# %%
u_PlankC
# Out:
#                    iv          RR1          RR4          RR5          RR6  \
# 0        Emiliania(A)     0.000000     0.000000  1507.673310  4882.038777
# 1       Helicosphaera     0.000000     0.000000     0.000000   699.818508
# 2    Rhabdosphaera(B)  1119.390322     0.000000     0.000000     0.000000
# 3        Chaetocerous     0.000000     0.000000   891.951559     0.000000
# 4           Corethron     0.000000     0.000000     0.000000     0.000000
# 5       Coscinodiscus   613.115330     0.000000   476.768163   903.461809
# 6      Fragilariopsis     0.000000     0.000000  3071.364038  2020.202020
# 7            Melosira     0.000000     0.000000     0.000000     0.000000
# 8                 P-N   867.076015   372.612948   583.919362  1806.923620
# 9       Planktoniella    15.662934     0.000000     0.000000     0.000000
# 10  Rhizo_Lg_fragment   191.190471   434.628771   799.270159   139.630816
# 11     Rhizo_Lg_Whole    54.257994   128.206637    41.440227   105.767047
# ...

# %%
#Dataframe formatting

#UNCERTAINTY DATAFRAMES (propagating Uncertainty by Addition)
unc_fluxes4carbon=u_fluxes4carbon.drop(['iv'],axis=1)
#
u_PlankC.index=u_PlankC['iv']#making one row of taxonomy the index names
un_PlankC=u_PlankC.drop(['iv'],axis=1)
unc_PlankC=un_PlankC.drop(['Rhizo_Lg_fragment'],axis=0)
sum_unc_PlankC=np.sqrt((unc_PlankC**2).sum(axis=0))

#
u_RhizC.index=u_RhizC['iv']#making one row of taxonomy the index names
un_RhizC=u_RhizC.drop(['iv'],axis=1)
unc_RhizC=un_RhizC.drop(['Foram'],axis=0)
unc_RhizC
sum_unc_RhizC=np.sqrt((unc_RhizC**2).sum(axis=0))
#

# %%
unc_fluxes4carbon
# Out:
#             RR1          RR4          RR5          RR6          RR7  \
# 0      0.000000     0.000000  1507.673310  4882.038777  4854.272779
# 1      0.000000     0.000000     0.000000   699.818508  1168.771539
# 2   1119.390322     0.000000     0.000000     0.000000     0.000000
# 3      0.000000     0.000000   891.951559     0.000000     0.000000
# 4      0.000000     0.000000     0.000000     0.000000     0.000000
# 5    613.115330     0.000000   476.768163   903.461809     0.000000
# 6      0.000000     0.000000  3071.364038  2020.202020  1981.748563
# 7      0.000000     0.000000     0.000000     0.000000     0.000000
# 8    867.076015   372.612948   583.919362  1806.923620     0.000000
# 9     15.662934     0.000000     0.000000     0.000000    18.284210
# 10   191.190471   434.628771   799.270159   139.630816   129.288887
# 11    54.257994   128.206637    41.440227   105.767047   189.133336
# 12     0.000000  2385.887000  3438.024114  2213.020434  1981.748563
# ...

# %%
dfFluxes_md.index=dfFluxes_md['iv']
dfCarbon_md.index=dfCarbon_md['iv']#making one row of taxonomy the index names
dfFluxes=dfFluxes_md.drop(['Rhizo_Lg_fragment','Foram'],axis=0)#Dropping_Rhizo_Frag_Row
dfCarbon=dfCarbon_md.drop(['Rhizo_Lg_fragment'],axis=0)#Dropping_Rhizo_Frag_Row

# %%
dfFluxes_No_only=dfFluxes.drop(['iv'],axis=1)
dfCarbon_No_only=dfCarbon.drop(['i','ii','iii','iv','V_um3','pgC'],axis=1)
dfFluxes_No_only=dfFluxes.drop(['i','ii','iii','iv'],axis=1)
dfCarbon_No_only['ugC'][:5]
# Out:
# iv
# Emiliania(A)        0.000405
# Helicosphaera       0.001084
# Rhabdosphaera(B)    0.001647
# Chaetocerous        0.000046
# Corethron           0.000013
# Name: ugC, dtype: float64

# %%
np.shape(dfCarbon_No_only)
# Out:
# (31, 1)

# %%
np.shape(dfFluxes_No_only)
# Out:
# (31, 30)

# %%
dfFluxes_No_only.multiply(dfCarbon_No_only['ugC'],axis=0)
# Out:
#                           RR1          RR4         RR5          RR6  \
# iv
# Acanth_B             4.326124     0.000000    0.000000     0.000000
# Aulocanthidae        0.000000    14.557996    0.000000     0.000000
# Aulosphaeridae       0.000000   375.335267  643.431885     0.000000
# Castanellidae        1.869976    31.789596   39.269501     0.000000
# Chaetocerous         0.000000     0.000000    2.264323     0.000000
# Challengeridae       0.000000     0.000000    0.000000     0.000000
# Cladococcus          4.448472     1.906488    0.000000     2.176092
# Coelodendridae       0.000000     0.000000  271.543309     0.000000
# Corethron            0.000000     0.000000    0.000000     0.000000
# Coscinodiscus      171.377799     0.000000  114.251865   326.021737
# Emiliania(A)              NaN          NaN         NaN          NaN
# Emiliania_(A)             NaN          NaN         NaN          NaN
# Fragilariopsis       0.000000     0.000000  165.836057    57.014343
# ...

# %%
Micrograms_of_C=dfFluxes_No_only.multiply(dfCarbon_No_only['ugC'],axis=0)
Micrograms_of_C
#
#Micrograms_of_C.index=dfFluxes['iv']#making one row of taxonomy the index names

#Micrograms_of_C.to_csv('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_Cell_Counts_/Micrograms_of_C.csv')
A_flux_sum=Micrograms_of_C.sum()
#Micrograms_of_C
#A_flux_sum
#Micrograms_of_C

# %%
#Total C fluxes(Rhiz&Phytoplankton) depth level averages, Epochs distinct
E1_100_avg=((A_flux_sum.loc['RR1']+A_flux_sum.loc['RR6']+A_flux_sum.loc['RR7'])/3)
E1_150_avg=A_flux_sum.loc['RR8']
E1_200_avg=((A_flux_sum.loc['RR9']+A_flux_sum.loc['RR10'])/2)
E1_330_avg=((A_flux_sum.loc['RR4']+A_flux_sum.loc['RR11'])/2)
E1_500=A_flux_sum.loc['RR5']
#
E2_100_avg=((A_flux_sum.loc['RR23']+A_flux_sum.loc['RR28']+A_flux_sum.loc['RR29'])/3)
E2_150_avg=((A_flux_sum.loc['RR30']+A_flux_sum.loc['RR24'])/2)
E2_200_avg=((A_flux_sum.loc['RR25']+A_flux_sum.loc['RR31']+A_flux_sum.loc['RR32'])/3)
E2_330_avg=((A_flux_sum.loc['RR33']+A_flux_sum.loc['RR26'])/2)
E2_500=A_flux_sum.loc['RR27']
#
E3_100_avg=((A_flux_sum.loc['RR53']+A_flux_sum.loc['RR54']+A_flux_sum.loc['RR58'])/3)
E3_150_avg=((A_flux_sum.loc['RR55']+A_flux_sum.loc['RR59'])/2)
E3_200_avg=((A_flux_sum.loc['RR56']+A_flux_sum.loc['RR60']/2))
E3_330_avg=((A_flux_sum.loc['RR57']+A_flux_sum.loc['RR61'])/2)
E3_500=A_flux_sum.loc['RR62']
#
df_avgE1=[E1_100_avg,E1_150_avg,E1_200_avg,E1_330_avg,E1_500]
df_avgE1
df_avgE2=[E2_100_avg,E2_150_avg,E2_200_avg,E2_330_avg,E2_500]
df_avgE2
df_avgE3=[E3_100_avg, E3_150_avg,E3_200_avg,E3_330_avg,E3_500]

# %%
#PlankC.sum()

# %%
#Phytoplankton Carbon fluxes averages by depth, Epochs Distinct
#Units are ug C m^-2 day^-1
p_sum=PlankC.sum()
pE1_100_avg=((p_sum.loc['RR1']+p_sum.loc['RR6']+p_sum.loc['RR7'])/3)
pE1_150_avg=p_sum.loc['RR8']
pE1_200_avg=((p_sum.loc['RR9']+p_sum.loc['RR10'])/2)
pE1_330_avg=((p_sum.loc['RR4']+p_sum.loc['RR11'])/2)
pE1_500=p_sum.loc['RR5']
#
pE2_100_avg=((p_sum.loc['RR23']+p_sum.loc['RR28']+p_sum.loc['RR29'])/3)
pE2_150_avg=((p_sum.loc['RR30']+p_sum.loc['RR24'])/2)
pE2_200_avg=((p_sum.loc['RR25']+p_sum.loc['RR31']+p_sum.loc['RR32'])/3)
pE2_330_avg=((p_sum.loc['RR33']+p_sum.loc['RR26'])/2)
pE2_500=p_sum.loc['RR27']
#
pE3_100_avg=((p_sum.loc['RR53']+p_sum.loc['RR54']+p_sum.loc['RR58'])/3)
pE3_150_avg=((p_sum.loc['RR55']+p_sum.loc['RR59'])/2)
pE3_200_avg=((p_sum.loc['RR56']+p_sum.loc['RR60']/2))
pE3_330_avg=((p_sum.loc['RR57']+p_sum.loc['RR61'])/2)
pE3_500=p_sum.loc['RR62']
pE2_330_avg
#
df_phyto_avgE1=[pE1_100_avg,pE1_150_avg,pE1_200_avg,pE1_330_avg,pE1_500]
df_phyto_avgE2=[pE2_100_avg,pE2_150_avg,pE2_200_avg,pE2_330_avg,pE2_500]
df_phyto_avgE3=[pE3_100_avg,pE3_150_avg,pE3_200_avg,pE3_330_avg,pE3_500]

# %%
print('Phytoplankton 100m Avg Epoch 1 (ug C m^-2 day^-1)')
print(pE1_100_avg)
print('')
print('Phytoplankton 500m Avg Epoch 1 (ug C m^-2 day^-1)')
print(pE1_500)
print('')
print('Phytoplankton 100m Avg Epoch 2 (ug C m^-2 day^-1)')
print(pE2_100_avg)
print('')
print('Phytoplankton 500m Avg Epoch 2 (ug C m^-2 day^-1)')
print(pE2_500)
print('')
print('Phytoplankton 100m Avg Epoch 3 (ug C m^-2 day^-1)')
print(pE3_100_avg)
print('')
print('Phytoplankton 500m Avg Epoch 3 (ug C m^-2 day^-1)')
print(pE3_500)
print('')
# Out:
# Phytoplankton 100m Avg Epoch 1 (ug C m^-2 day^-1)
# 1297.059095596
#
# Phytoplankton 500m Avg Epoch 1 (ug C m^-2 day^-1)
# 870.932779251
#
# Phytoplankton 100m Avg Epoch 2 (ug C m^-2 day^-1)
# 1084.1484333246667
#
# Phytoplankton 500m Avg Epoch 2 (ug C m^-2 day^-1)
# 2119.860495047
#
# Phytoplankton 100m Avg Epoch 3 (ug C m^-2 day^-1)
# 345.5975821643333
#
# Phytoplankton 500m Avg Epoch 3 (ug C m^-2 day^-1)
# 2295.6388110400003

# %%
mmol_pE1_100_avg=((p_sum.loc['RR1']+p_sum.loc['RR6']+p_sum.loc['RR7'])/3)/12011
mmol_pE1_150_avg=p_sum.loc['RR8']/12000
mmol_pE1_200_avg=((p_sum.loc['RR9']+p_sum.loc['RR10'])/2)/12011 
mmol_pE1_330_avg=((p_sum.loc['RR4']+p_sum.loc['RR11'])/2)/12011
mmol_pE1_500=p_sum.loc['RR5']/12000
#
mmol_pE2_100_avg=((p_sum.loc['RR23']+p_sum.loc['RR28']+p_sum.loc['RR29'])/3)/12011
mmol_pE2_150_avg=((p_sum.loc['RR30']+p_sum.loc['RR24'])/2)/12011
mmol_pE2_200_avg=((p_sum.loc['RR25']+p_sum.loc['RR31']+p_sum.loc['RR32'])/3)/12011
mmol_pE2_330_avg=((p_sum.loc['RR33']+p_sum.loc['RR26'])/2)/12011
mmol_pE2_500=p_sum.loc['RR27']/12011
#
mmol_pE3_100_avg=((p_sum.loc['RR53']+p_sum.loc['RR54']+p_sum.loc['RR58'])/3)/12011
mmol_pE3_150_avg=((p_sum.loc['RR55']+p_sum.loc['RR59'])/2)/12011
mmol_pE3_200_avg=((p_sum.loc['RR56']+p_sum.loc['RR60']/2))/12011
mmol_pE3_330_avg=((p_sum.loc['RR57']+p_sum.loc['RR61'])/2)/12011
mmol_pE3_500=p_sum.loc['RR62']/12011

#
df_phyto_avgE1=[pE1_100_avg,pE1_150_avg,pE1_200_avg,pE1_330_avg,pE1_500]
df_phyto_avgE2=[pE2_100_avg,pE2_150_avg,pE2_200_avg,pE2_330_avg,pE2_500]
df_phyto_avgE3=[pE3_100_avg,pE3_150_avg,pE3_200_avg,pE3_330_avg,pE3_500]

# %%
print('Phytoplankton 100m Avg Epoch 1 (mmol C m^-2 day^-1)')
print(mmol_pE1_100_avg)
print('')
print('Phytoplankton 500m Avg Epoch 1 (mmol C m^-2 day^-1)')
print(mmol_pE1_500)
print('')
print('Phytoplankton 100m Avg Epoch 2 (mmol C m^-2 day^-1)')
print(mmol_pE2_100_avg)
print('')
print('Phytoplankton 500m Avg Epoch 2 (mmol C m^-2 day^-1)')
print(mmol_pE2_500)
print('')
print('Phytoplankton 100m Avg Epoch 3 (mmol C m^-2 day^-1)')
print(mmol_pE3_100_avg)
print('')
print('Phytoplankton 500m Avg Epoch 3 (mmol C m^-2 day^-1)')
print(mmol_pE3_500)
print('')
# Out:
# Phytoplankton 100m Avg Epoch 1 (mmol C m^-2 day^-1)
# 0.1079892678041795
#
# Phytoplankton 500m Avg Epoch 1 (mmol C m^-2 day^-1)
# 0.07257773160425
#
# Phytoplankton 100m Avg Epoch 2 (mmol C m^-2 day^-1)
# 0.09026296172880416
#
# Phytoplankton 500m Avg Epoch 2 (mmol C m^-2 day^-1)
# 0.17649325576946132
#
# Phytoplankton 100m Avg Epoch 3 (mmol C m^-2 day^-1)
# 0.028773422876058056
#
# Phytoplankton 500m Avg Epoch 3 (mmol C m^-2 day^-1)
# 0.1911280335559071

# %%
RhizCx
# Out:
#                        RR1         RR4         RR5          RR6        RR7  \
# iv
# Aulocanthidae     0.000000   14.557996    0.000000     0.000000   0.000000
# Aulosphaeridae    0.000000  375.335267  643.431885     0.000000   0.000000
# Castanellidae     1.869976   31.789596   39.269501     0.000000   2.182927
# Challengeridae    0.000000    0.000000    0.000000     0.000000   0.000000
# Coelodendridae    0.000000    0.000000  271.543309     0.000000   0.000000
# Phaeocochidae     0.136658    1.093268    0.136658     0.000000   0.000000
# Acanth_B          4.326124    0.000000    0.000000     0.000000   0.000000
# Cladococcus       4.448472    1.906488    0.000000     2.176092   2.967398
# Litharachnium     0.000000    1.283907    0.320977     0.000000   0.000000
# Nass_A_B-C-D-E  314.092390   31.409239  345.501628     0.000000   0.000000
# Nass_F            0.000000    0.000000    0.000000     0.000000   0.000000
# ...

# %%
r_sum=RhizCx.sum()
rE1_100_avg=((r_sum.loc['RR1']+r_sum.loc['RR6']+r_sum.loc['RR7'])/3)
rE1_150_avg=r_sum.loc['RR8']
rE1_200_avg=((r_sum.loc['RR9']+r_sum.loc['RR10'])/2)
rE1_330_avg=((r_sum.loc['RR4']+r_sum.loc['RR11'])/2)
rE1_500=r_sum.loc['RR5']
#
rE2_100_avg=((r_sum.loc['RR23']+r_sum.loc['RR28']+r_sum.loc['RR29'])/3)
rE2_150_avg=((r_sum.loc['RR30']+r_sum.loc['RR24'])/2)
rE2_200_avg=((r_sum.loc['RR25']+r_sum.loc['RR31']+r_sum.loc['RR32'])/3)
rE2_330_avg=((r_sum.loc['RR33']+r_sum.loc['RR26'])/2)
rE2_500=r_sum.loc['RR27']
#
rE3_100_avg=((r_sum.loc['RR53']+r_sum.loc['RR54']+r_sum.loc['RR58'])/3)
rE3_150_avg=((r_sum.loc['RR55']+r_sum.loc['RR59'])/2)
rE3_200_avg=((r_sum.loc['RR56']+r_sum.loc['RR60']/2))
rE3_330_avg=((r_sum.loc['RR57']+r_sum.loc['RR61'])/2)
rE3_500=r_sum.loc['RR62']

df_rhiz_avgE1=[rE1_100_avg,rE1_150_avg,rE1_200_avg,rE1_330_avg,rE1_500]
df_rhiz_avgE2=[rE2_100_avg,rE2_150_avg,rE2_200_avg,rE2_330_avg,rE2_500]
df_rhiz_avgE3=[rE3_100_avg,rE3_150_avg,rE3_200_avg,rE3_330_avg,rE3_500]

# %%
r_sum=RhizCx.sum()
mmol_rE1_100_avg=((r_sum.loc['RR1']+r_sum.loc['RR6']+r_sum.loc['RR7'])/3)/12000
mmol_rE1_150_avg=r_sum.loc['RR8']/12000
mmol_rE1_200_avg=((r_sum.loc['RR9']+r_sum.loc['RR10'])/2)/12000
mmol_rE1_330_avg=((r_sum.loc['RR4']+r_sum.loc['RR11'])/2)/12000
mmol_rE1_500=r_sum.loc['RR5']/12000
#
mmol_rE2_100_avg=((r_sum.loc['RR23']+r_sum.loc['RR28']+r_sum.loc['RR29'])/3)/12000
mmol_rE2_150_avg=((r_sum.loc['RR30']+r_sum.loc['RR24'])/2)/12000
mmol_rE2_200_avg=((r_sum.loc['RR25']+r_sum.loc['RR31']+r_sum.loc['RR32'])/3)/12000
mmol_rE2_330_avg=((r_sum.loc['RR33']+r_sum.loc['RR26'])/2)/12000
mmol_rE2_500=r_sum.loc['RR27']/12000
#
mmol_rE3_100_avg=((r_sum.loc['RR53']+r_sum.loc['RR54']+r_sum.loc['RR58'])/3)/12000
mmol_rE3_150_avg=((r_sum.loc['RR55']+r_sum.loc['RR59'])/2)/12000
mmol_rE3_200_avg=((r_sum.loc['RR56']+r_sum.loc['RR60']/2))/12000
mmol_rE3_330_avg=((r_sum.loc['RR57']+r_sum.loc['RR61'])/2)/12000
mmol_rE3_500=r_sum.loc['RR62']/12000

mmol_df_rhiz_avgE1=[rE1_100_avg,rE1_150_avg,rE1_200_avg,rE1_330_avg,rE1_500]
mmol_df_rhiz_avgE2=[rE2_100_avg,rE2_150_avg,rE2_200_avg,rE2_330_avg,rE2_500]
mmol_df_rhiz_avgE3=[rE3_100_avg,rE3_150_avg,rE3_200_avg,rE3_330_avg,rE3_500]

# %%
print('Rhizaria 100m Avg Epoch 1 (mmol C m^-2 day^-1)')
print(mmol_rE1_100_avg)
print('')
print('Rhizaria 500m Avg Epoch 1 (mmol C m^-2 day^-1)')
print(mmol_rE1_500)
print('')
print('Rhizaria 100m Avg Epoch 2 (mmol C m^-2 day^-1)')
print(mmol_rE2_100_avg)
print('')
print('Rhizaria 500m Avg Epoch 2 (mmol C m^-2 day^-1)')
print(mmol_rE2_500)
print('')
print('Rhizaria 100m Avg Epoch 3 (mmol C m^-2 day^-1)')
print(mmol_rE3_100_avg)
print('')
print('Rhizaria 500m Avg Epoch 3 (mmol C m^-2 day^-1)')
print(mmol_rE3_500)
print('')
# Out:
# Rhizaria 100m Avg Epoch 1 (mmol C m^-2 day^-1)
# 0.09928747196869445
#
# Rhizaria 500m Avg Epoch 1 (mmol C m^-2 day^-1)
# 0.10938310110949999
#
# Rhizaria 100m Avg Epoch 2 (mmol C m^-2 day^-1)
# 0.014073831459194445
#
# Rhizaria 500m Avg Epoch 2 (mmol C m^-2 day^-1)
# 0.06488972901358334
#
# Rhizaria 100m Avg Epoch 3 (mmol C m^-2 day^-1)
# 0.04406815190136112
#
# Rhizaria 500m Avg Epoch 3 (mmol C m^-2 day^-1)
# 0.09230144795808333

# %%
print('Rhizaria 100m Avg Epoch 1 (ug C m^-2 day^-1)')
print(rE1_100_avg)
print('')
print('Rhizaria 500m Avg Epoch 1 (ug C m^-2 day^-1)')
print(rE1_500)
print('')
print('Rhizaria 100m Avg Epoch 2 (ug C m^-2 day^-1)')
print(rE2_100_avg)
print('')
print('Rhizaria 500m Avg Epoch 2 (ug C m^-2 day^-1)')
print(rE2_500)
print('')
print('Rhizaria 100m Avg Epoch 3 (ug C m^-2 day^-1)')
print(rE3_100_avg)
print('')
print('Rhizaria 500m Avg Epoch 3 (ug C m^-2 day^-1)')
print(rE3_500)
print('')
# Out:
# Rhizaria 100m Avg Epoch 1 (ug C m^-2 day^-1)
# 1191.4496636243334
#
# Rhizaria 500m Avg Epoch 1 (ug C m^-2 day^-1)
# 1312.5972133139999
#
# Rhizaria 100m Avg Epoch 2 (ug C m^-2 day^-1)
# 168.88597751033333
#
# Rhizaria 500m Avg Epoch 2 (ug C m^-2 day^-1)
# 778.676748163
#
# Rhizaria 100m Avg Epoch 3 (ug C m^-2 day^-1)
# 528.8178228163334
#
# Rhizaria 500m Avg Epoch 3 (ug C m^-2 day^-1)
# 1107.617375497

# %% [markdown]
# # Readying Metadata variables from flux DFs in preperation for plotting Carbon Fluxes

# %%
A_flux_sum
# Out:
# RR1     1506.882343
# RR4     3551.502940
# RR5     2125.988025
# RR6     4217.480201
# RR7      585.788681
# RR8      551.401480
# RR9     1039.091143
# RR10     510.813697
# RR11     889.714331
# RR23    1110.352506
# RR24     635.914601
# RR25    3666.111018
# RR26    4453.939096
# RR27    2898.359335
# RR28     503.467012
# RR29     855.803707
# RR30    5358.280159
# RR31    1303.361301
# RR32    2586.448277
# RR33    1751.833234
# RR53     594.994208
# RR54    1416.018207
# RR55      88.417645
# RR56     378.923347
# RR57     825.519367
# RR58     585.103511
# RR59    1143.432716
# RR60    1748.285718
# RR61    3162.175594
# RR62    3260.236346
# dtype: float64

# %%
Ametadata = dfA.loc[dfA.group == 'metadata']
Ametadata_numbers = Ametadata.drop(['group','group.1','Category'],axis=1) #columns
depth=Ametadata.loc[Ametadata.Category=='True_Depth_(m)']
Epochs=Ametadata.loc[Ametadata.Category=='Epoch']
Epoch_1=np.where(Epochs=='1')
Epoch_2=np.where(Epochs=='2')
Epoch_3=np.where(Epochs=='3')
E1_traps=Epochs.columns[Epoch_1[1]]
E2_traps=Epochs.columns[Epoch_2[1]]
E3_traps=Epochs.columns[Epoch_3[1]]
E1_traps=Epochs.columns[Epoch_1[1]]
E2_traps=Epochs.columns[Epoch_2[1]]
E3_traps=Epochs.columns[Epoch_3[1]]
E1_flux=A_flux_sum[E1_traps].astype(float).values
E2_flux=A_flux_sum[E2_traps].astype(float).values
E3_flux=A_flux_sum[E3_traps].astype(float).values
E1_depths=depth[E1_traps].astype(float).values[0]
E2_depths=depth[E2_traps].astype(float).values[0]
E3_depths=depth[E3_traps].astype(float).values[0]
depthsthreeA=[92.0, 160.0, 207.0, 345.0, 496.0,92.0, 160.0, 207.0, 345.0, 496.0,92.0, 160.0, 207.0, 345.0, 496.0,]
depthsthreeB=[100.0, 159.0, 209.0, 330.0, 500.0,95.0, 159.0, 209.0, 330.0, 500.0,100, 159.0, 209.0, 330.0, 500.0]
depthstwoA=[92.0, 160.0, 207.0, 345.0, 496.0,92.0, 160.0, 207.0, 345.0, 496.0]
depthstwoB=[100, 159.0, 209.0, 330.0, 500.0,100.0, 159.0, 209.0, 330.0, 500.0]
depth_bins=[E1_depths[0],E1_depths[5],E1_depths[6],E1_depths[1],E1_depths[2]]

# %%
rE1_flux=r_sum[E1_traps].astype(float).values
rE2_flux=r_sum[E2_traps].astype(float).values
rE3_flux=r_sum[E3_traps].astype(float).values
#
pE1_flux=p_sum[E1_traps].astype(float).values
pE2_flux=p_sum[E2_traps].astype(float).values
pE3_flux=p_sum[E3_traps].astype(float).values

# %%
E1_flux=A_flux_sum[E1_traps].astype(float).values
E1_flux
# Out:
# array([1506.88234333, 3551.50294004, 2125.98802459, 4217.48020111,
#         585.78868102,  551.40148048, 1039.09114258,  510.81369654,
#         889.71433061])

# %%
rE1_flux
# Out:
# array([ 324.8736198 ,  957.4444174 , 1312.59721331, 3226.5997152 ,
#          22.87565588,  314.81487338,  554.39303235,   97.82028026,
#         540.09777873])

# %%
r_sum[E1_traps]
# Out:
# RR1      324.873620
# RR4      957.444417
# RR5     1312.597213
# RR6     3226.599715
# RR7       22.875656
# RR8      314.814873
# RR9      554.393032
# RR10      97.820280
# RR11     540.097779
# dtype: float64

# %% [markdown]
# #Total C fluxes(Rhiz&Phytoplankton) depth level averages, Epochs distinct
# E1_100_avg=((A_flux_sum.loc['RR1']+A_flux_sum.loc['RR6']+A_flux_sum.loc['RR7'])/3)
# E1_150_avg=A_flux_sum.loc['RR8']
# E1_200_avg=((A_flux_sum.loc['RR9']+A_flux_sum.loc['RR10'])/2)
# E1_330_avg=((A_flux_sum.loc['RR4']+A_flux_sum.loc['RR11'])/2)
# E1_500=A_flux_sum.loc['RR5']
# #
# E2_100_avg=((A_flux_sum.loc['RR23']+A_flux_sum.loc['RR28']+A_flux_sum.loc['RR29'])/3)
# E2_150_avg=((A_flux_sum.loc['RR30']+A_flux_sum.loc['RR24'])/2)
# E2_200_avg=((A_flux_sum.loc['RR25']+A_flux_sum.loc['RR31']+A_flux_sum.loc['RR32'])/3)
# E2_330_avg=((A_flux_sum.loc['RR33']+A_flux_sum.loc['RR26'])/2)
# E2_500=A_flux_sum.loc['RR27']
# #
# E3_100_avg=((A_flux_sum.loc['RR53']+A_flux_sum.loc['RR54']+A_flux_sum.loc['RR58'])/3)
# E3_150_avg=((A_flux_sum.loc['RR55']+A_flux_sum.loc['RR59'])/2)
# E3_200_avg=((A_flux_sum.loc['RR56']+A_flux_sum.loc['RR60']/2))
# E3_330_avg=((A_flux_sum.loc['RR57']+A_flux_sum.loc['RR61'])/2)
# E3_500=A_flux_sum.loc['RR62']
# #
# df_avgE1=[E1_100_avg,E1_150_avg,E1_200_avg,E1_330_avg,E1_500]
# df_avgE1
# df_avgE2=[E2_100_avg,E2_150_avg,E2_200_avg,E2_330_avg,E2_500]
# df_avgE2
# df_avgE3=[E3_100_avg, E3_150_avg,E3_200_avg,E3_330_avg,E3_500]

# %%
unc_fluxes4carbon.index=dfFluxes_md['iv']
sum_unc_fluxes4carbon=np.sqrt((unc_fluxes4carbon**2).sum(axis=0))
#
uncE1_flux=sum_unc_fluxes4carbon[E1_traps].astype(float).values
uncE2_flux=sum_unc_fluxes4carbon[E2_traps].astype(float).values
uncE3_flux=sum_unc_fluxes4carbon[E3_traps].astype(float).values

# %%
unc_fluxes4carbon
# Out:
#                            RR1          RR4          RR5          RR6  \
# iv
# Emiliania_(A)         0.000000     0.000000  1507.673310  4882.038777
# Helicosphaera_(B)     0.000000     0.000000     0.000000   699.818508
# Rhabdosphaera      1119.390322     0.000000     0.000000     0.000000
# Chaetocerous          0.000000     0.000000   891.951559     0.000000
# Corethron             0.000000     0.000000     0.000000     0.000000
# Coscinodiscus       613.115330     0.000000   476.768163   903.461809
# Fragilariopsis        0.000000     0.000000  3071.364038  2020.202020
# Melosira              0.000000     0.000000     0.000000     0.000000
# P-N                 867.076015   372.612948   583.919362  1806.923620
# Planktoniella        15.662934     0.000000     0.000000     0.000000
# Rhizo_Lg_fragment   191.190471   434.628771   799.270159   139.630816
# Rhizo_Lg_Whole       54.257994   128.206637    41.440227   105.767047
# ...

# %%
#plt.plot(Thalassiosira[E1_traps].values[0],E1_depths,'o',color='mediumorchid',label='Epoch_1')

#plt.errorbar(Thalassiosira[E1_traps],E1_depths,xerr=unc_A_flux_sum[E1_traps],

#ecolor='deepseagreen',marker='o',ms=6,lw=2,elinewidth=1,color='darkseagreen',label='Epoch_1')
#plt.errorbar(x, y, xerr=, fmt='o', color='black',
             #ecolor='lightgray', elinewidth=3, capsize=0);
#plt.errorbar(E1_flux,E1_depths,xerr=unc_fluxes4carbon[uncE1_flux],ecolor=black,elinewidth=10,'o',capsize=0,color='c',label='Epoch 1')

# %%
E1_flux
# Out:
# array([1506.88234333, 3551.50294004, 2125.98802459, 4217.48020111,
#         585.78868102,  551.40148048, 1039.09114258,  510.81369654,
#         889.71433061])

# %%
uncE1_flux
# Out:
# array([2248.13028651, 2487.22156526, 5284.74554909, 6542.38397626,
#        5745.42358145, 2732.62884747, 4919.41495824, 3855.26544288,
#        5639.62822106])

# %%
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = False
plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.labeltop'] = True
plt.figure(figsize=[10,7])
plt.subplot(1,3,1)
plt.errorbar(E1_flux,E1_depths,xerr=uncE1_flux,color='c',fmt='o',label='Epoch 1',ecolor='black',elinewidth=2)
plt.plot(df_avgE1,depth_bins,'-',lw=5,color='darkcyan')
plt.ylim(550,0)
#plt.xlim(0,360000)
#plt.xticks([0,1e5,2e5,3e5],labels=['0','100','200','300'],size=12)
plt.xlim(0,8.1e4)
plt.xticks([0,4e4,8e4],labels=['0','40000','80000'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['0','100','200','300','400','500'],size=20)
plt.legend(fontsize=15)
#
plt.subplot(1,3,2)
plt.title( 'C Flux of all cells ug C m^-2 day-1',size=17)
plt.errorbar(E2_flux,E2_depths,xerr=uncE2_flux,color='green',fmt='o',label='Epoch 2',ecolor='black',elinewidth=2)
#plt.plot(E2_flux, E2_depths,'o',color='green',label='Epoch 2')
plt.plot(df_avgE2,depth_bins,'-',lw=5,color='green')
#plt.xlabel('cells/m2/day')
plt.ylim(550,0)
plt.xlim(0,8.1e4)
plt.xticks([0,4e4,8e4],labels=['0','40000','80000'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
#plt.title('Total Cell Flux')
#
plt.subplot(1,3,3)
plt.errorbar(E3_flux,E3_depths,xerr=uncE3_flux,color='dimgrey',fmt='o',label='Epoch 3',ecolor='black',elinewidth=2)
#plt.plot(E3_flux,E3_depths,'o',color='dimgrey',label='Epoch 3')
plt.plot(df_avgE3,depth_bins,'-',lw=5,color='dimgrey')
plt.ylim(550,0)
plt.xlim(0,8.1e4)
plt.xticks([0,4e4,8e4],labels=['0','40000','80000'],size=12)
#plt.xlim(0,360000)
#plt.xticks([0,1e5,2e5,3e5],labels=['0','100','200','300'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
plt.tight_layout()
#plt.savefig('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_plots_jpegs/FEB14_Total_cell_flux_EPOCHS.jpeg')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = False
plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.labeltop'] = True
plt.figure(figsize=[10,7])
plt.subplot(1,3,1)
plt.errorbar(E1_flux,E1_depths,xerr=uncE1_flux,color='c',fmt='o',label='Epoch 1',ecolor='black',elinewidth=2)
plt.plot(df_avgE1,depth_bins,'-',lw=5,color='darkcyan')
plt.ylim(550,0)
plt.xlim(0,2e4)
plt.xticks([0,1e4,2e4],labels=['0','10000','20000'],size=12)
#plt.xlim(0,360000)
#plt.xticks([0,1e5,2e5,3e5],labels=['0','100','200','300'],size=12)
#plt.xlim(0,8.1e4)
#plt.xticks([0,4e4,8e4],labels=['0','40000','80000'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['0','100','200','300','400','500'],size=20)
plt.legend(fontsize=15)
#
plt.subplot(1,3,2)
plt.title( 'C Flux of all cells ug C m^-2 day-1',size=17)
plt.errorbar(E2_flux,E2_depths,xerr=uncE2_flux,color='green',fmt='o',label='Epoch 2',ecolor='black',elinewidth=2)
#plt.plot(E2_flux, E2_depths,'o',color='green',label='Epoch 2')
plt.plot(df_avgE2,depth_bins,'-',lw=5,color='green')
#plt.xlabel('cells/m2/day')
plt.ylim(550,0)
plt.xlim(0,8.1e4)
plt.xticks([0,4e4,8e4],labels=['0','40000','80000'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
#plt.title('Total Cell Flux')
#
plt.subplot(1,3,3)
plt.errorbar(E3_flux,E3_depths,xerr=uncE3_flux,color='dimgrey',fmt='o',label='Epoch 3',ecolor='black',elinewidth=2)
#plt.plot(E3_flux,E3_depths,'o',color='dimgrey',label='Epoch 3')
plt.plot(df_avgE3,depth_bins,'-',lw=5,color='dimgrey')
plt.ylim(550,0)
plt.xlim(0,2e4)
plt.xticks([0,1e4,2e4],labels=['0','10000','20000'],size=12)
#plt.xlim(0,360000)
#plt.xticks([0,1e5,2e5,3e5],labels=['0','100','200','300'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
plt.tight_layout()
#plt.savefig('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_plots_jpegs/FEB14_Total_cell_flux_EPOCHS.jpeg')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
rE1_flux
# Out:
# array([ 324.8736198 ,  957.4444174 , 1312.59721331, 3226.5997152 ,
#          22.87565588,  314.81487338,  554.39303235,   97.82028026,
#         540.09777873])

# %%
df_rhiz_avgE1
# Out:
# [1191.4496636243334,
#  314.81487338,
#  326.1066563065,
#  748.7710980615,
#  1312.5972133139999]

# %%
sum_unc_RhizC[E1_traps]
# Out:
# RR1     1460.262626
# RR4      103.896148
# RR5     1220.057769
# RR6     1937.957110
# RR7       40.884736
# RR8      604.255735
# RR9     1043.355940
# RR10      85.196990
# RR11     540.629555
# dtype: float64

# %%
unc_RhizC[E1_traps]
# Out:
#                         RR1        RR4          RR5          RR6       RR7  \
# iv
# Aulocanthidae      0.000000  31.325867     0.000000     0.000000   0.00000
# Aulosphaeridae     0.000000  41.440227    54.257994     0.000000   0.00000
# Castanellidae     15.662934  64.579930    71.776579     0.000000  18.28421
# Challengeridae     0.000000   0.000000     0.000000     0.000000   0.00000
# Coelodendridae     0.000000   0.000000    35.023384     0.000000   0.00000
# Phaeoconchidae    15.662934  44.301466    15.662934     0.000000   0.00000
# Acanth_B           0.000000   0.000000     0.000000     0.000000   0.00000
# Cladococcus       41.440227  27.128997     0.000000    30.965421  36.56842
# Litharachnium      0.000000  31.325867    15.662934     0.000000   0.00000
# Nass_A_B-C-D-E  1459.506420   0.000000  1118.120450     0.000000   0.00000
# Nass_F             0.000000   0.000000     0.000000     0.000000   0.00000
# ...

# %%
#ax3.set_ylim([510,50])
#ax3.set_yticks([100,200,300,400,500])
#ax3.set_yticklabels(['','','','','',''],fontsize=20)
#ax3.set_xlim([0,1e7])
#ax3.set_xticks([0,0.5e7,1e7])
#ax3.set_xticklabels(['0','5','10'],fontsize='x-large')
#ax3.set_title('Epoch 3',fontsize=20)
#ylabel(ylabel, fontdict=None, labelpad=None,

plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = False
plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.labeltop'] = True
plt.figure(figsize=[10,7])
plt.subplot(1,3,1)
plt.errorbar(rE1_flux,E1_depths,xerr=sum_unc_RhizC[E1_traps],color='darkslateblue',fmt='o',label='Epoch 1',ecolor='black',elinewidth=2)

#plt.plot(rE1_flux,E1_depths,'o',color='darkslateblue',label='Epoch 1')

plt.plot(df_rhiz_avgE1,depth_bins,'-',lw=5,color='indigo')
plt.ylim(550,0)
plt.xlim(0,10000)
plt.xticks([0,3000,6000,9000],labels=['0','3','6','9'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['0','100','200','300','400','500'],size=20)
plt.legend(fontsize=15)
#
plt.subplot(1,3,2)
plt.title( 'C Flux of Rhizaria cells mg C m^-2 day-1',size=17)
plt.errorbar(rE2_flux,E2_depths,xerr=sum_unc_RhizC[E2_traps],color='royalblue',fmt='o',label='Epoch 2',ecolor='black',elinewidth=2)
#plt.plot(rE2_flux, E2_depths,'o',color='royalblue',label='Epoch 2')
plt.plot(df_rhiz_avgE2,depth_bins,'-',lw=5,color='blue')
#plt.xlabel('cells/m2/day')
plt.ylim(550,0)
plt.xlim(0,13000)
plt.xticks([0,3000,6000,9000,12000],labels=['0','3','6','9','12'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
#plt.title('Total Cell Flux')
#
plt.subplot(1,3,3)
#plt.plot(rE3_flux,E3_depths,'o',color='navy',label='Epoch 3')
plt.errorbar(rE3_flux,E3_depths,xerr=sum_unc_RhizC[E3_traps],color='navy',fmt='o',label='Epoch 3',ecolor='black',elinewidth=2)
plt.plot(df_rhiz_avgE3,depth_bins,'-',lw=5,color='midnightblue')
plt.ylim(550,0)
plt.xlim(0,10000)
plt.xlim(0,10000)
plt.xticks([0,2500,5000,7000,10000],labels=['0','2.5','5','7','10'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
plt.tight_layout()
#plt.savefig('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_plots_jpegs/FEB14_Total_cell_flux_EPOCHS.jpeg')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Propagating Uncertainty for combined taxa

# %%
#General method for calculating counting uncertainty from cell counts:
#Adays=Ametadata_numbers.loc[Ametadata.Category=='Elapsed_Time_(days)']
#fields=Ametadata_numbers.loc[Ametadata.Category=='Fields'].astype(float)
#m2perfield=Ametadata_numbers.loc[Ametadata.Category=='m2perfield']
#m2perfield
#cell_unc=np.sqrt(Acell_counts)
#cell_unc
#cells_unc_per_fields=cell_unc.divide(Ametadata_numbers.iloc[0].astype(float))
#cells_unc_per_m2=cells_unc_per_fields.divide(Ametadata_numbers.iloc[1].astype(float))
#cells_unc_per_m2[:3]
#cell_unc_flux=cells_unc_per_m2.divide(Ametadata_numbers.iloc[2].astype(float))
#cell_unc_flux[:1]

# %%
#Uncertainty of my summed taxa fluxes: square unc-flux numbers. sum all. take square root unc_squared=unc_combined_df**2
#A_flux_sum=combined_df.sum(axis=0)
#unc_combined_df=dfB.drop([dfB.loc[dfB.Category=='Foraminifera'].index[0]])
#To get rid of all string headings!!! select_dtypes
#unc_combined_df_numbers=unc_combined_df.select_dtypes(include='float64')
#
#unc2=unc_combined_df_numbers**2
#unc3=unc2.sum(axis=0)
#unc_A_flux_sum=np.sqrt(unc3)

# %%
#ax3.set_ylim([510,50])
#ax3.set_yticks([100,200,300,400,500])
#ax3.set_yticklabels(['','','','','',''],fontsize=20)
#ax3.set_xlim([0,1e7])
#ax3.set_xticks([0,0.5e7,1e7])
#ax3.set_xticklabels(['0','5','10'],fontsize='x-large')
#ax3.set_title('Epoch 3',fontsize=20)
#ylabel(ylabel, fontdict=None, labelpad=None,

plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.bottom'] = False
plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.labeltop'] = True
plt.figure(figsize=[10,7])
plt.subplot(1,3,1)
plt.errorbar(pE1_flux,E1_depths,xerr=sum_unc_PlankC[E1_traps],color='teal',fmt='o',label='Epoch 1',ecolor='black',elinewidth=2)

#plt.plot(rE1_flux,E1_depths,'o',color='darkslateblue',label='Epoch 1')

plt.plot(df_phyto_avgE1,depth_bins,'-',lw=5,color='lightseagreen')
plt.ylim(550,0)
#plt.xlim(0,10000)
#plt.xticks([0,3000,6000,9000],labels=['0','3','6','9'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['0','100','200','300','400','500'],size=20)
plt.legend(fontsize=15)
#
plt.subplot(1,3,2)
plt.title( 'C Flux of Phytoplank cells ug C m^-2 day-1',size=17)
plt.errorbar(rE2_flux,E2_depths,xerr=sum_unc_PlankC[E2_traps],color='mediumspringgreen',fmt='o',label='Epoch 2',ecolor='black',elinewidth=2)
#plt.plot(rE2_flux, E2_depths,'o',color='royalblue',label='Epoch 2')
plt.plot(df_phyto_avgE2,depth_bins,'-',lw=5,color='mediumseagreen')
#plt.xlabel('cells/m2/day')
plt.ylim(550,0)
#plt.xlim(0,13000)
#plt.xticks([0,3000,6000,9000,12000],labels=['0','3','6','9','12'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
#plt.title('Total Cell Flux')
#
plt.subplot(1,3,3)
#plt.plot(rE3_flux,E3_depths,'o',color='navy',label='Epoch 3')
plt.errorbar(pE3_flux,E3_depths,xerr=sum_unc_PlankC[E3_traps],color='darkolivegreen',fmt='o',label='Epoch 3',ecolor='black',elinewidth=2)
plt.plot(df_phyto_avgE3,depth_bins,'-',lw=5,color='darkolivegreen')
plt.ylim(550,0)
plt.xlim(0,10000)
#plt.xlim(0,10000)
#plt.xticks([0,2500,5000,7000,10000],labels=['0','2.5','5','7','10'],size=12)
plt.yticks([0,100,200,300,400,500],labels=['','','','','',''])
plt.legend(fontsize=15)
plt.tight_layout()
#plt.savefig('/Users/alb/PROJECTS/EXPORTS/EXPORTS_1/EXPORTS_plots_jpegs/FEB14_Total_cell_flux_EPOCHS.jpeg')
# Out:
# <img src="data:image/png;base64,..." width="1000">
